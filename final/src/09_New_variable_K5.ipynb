# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import scale

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.initializers import Initializer
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
raw_data = pd.read_csv('./data/ordered_molecules.csv')

# %%
raw_data.head()
# Out:
#    time  molecule        px        py       pz        ax        ay        az
# 0     0         1   0.27497   0.22765  0.40548  1.185458 -1.527830 -4.614324
# 1     0         2   2.13410   1.61428  1.62211 -4.601109 -0.659241  1.090967
# 2     0         3  12.05408  12.60878  2.90295  4.530882 -2.598597  2.008448
# 3     0         4   0.85376   1.93829  4.87515  3.975239  0.917088 -2.261618
# 4     0         5  12.70257   0.12956  6.09076 -1.861295 -0.908830  5.337542

# %%
#raw_data_scaled = pd.DataFrame(scale(raw_data.iloc[:,2:], axis = 0))
#raw_data_scaled = pd.concat([raw_data.iloc[:,0:2].reset_index(drop=True), raw_data_scaled.reset_index(drop=True)], axis = 1)

# %%
#raw_data_scaled

# %%
def generate_data(t):
    df = raw_data.loc[raw_data['time'] == t]
    
    px_plus = df.iloc[:,2] + 12.9168567587204
    px_origin = df.iloc[:,2]
    px_minus = df.iloc[:,2] - 12.9168567587204
    
    py_plus = df.iloc[:,3] + 12.9168567587204
    py_origin = df.iloc[:,3]
    py_minus = df.iloc[:,3] - 12.9168567587204
    
    pz_plus = df.iloc[:,4] + 12.9168567587204
    pz_origin = df.iloc[:,4]
    pz_minus = df.iloc[:,4] - 12.9168567587204
    
    #plus
    data_mod_1 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_2 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_3 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_4 = pd.concat((px_plus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_5 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_6 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_7 = pd.concat((px_plus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    #minus
    data_mod_8 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_9 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_10 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_11 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_12 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_13 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_14 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    #plus + minus
    data_mod_15 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_16 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_17 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_18 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    
    data_mod_19 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_20 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    #3
    data_mod_21 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_22 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_23 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_24 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_25 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_26 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_27 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    
    combined_df = pd.concat([data_mod_27.reset_index(drop=True), data_mod_1.reset_index(drop=True), data_mod_2.reset_index(drop=True), data_mod_3.reset_index(drop=True), 
                           data_mod_4.reset_index(drop=True), data_mod_5.reset_index(drop=True), data_mod_6.reset_index(drop=True), data_mod_7.reset_index(drop=True), 
                           data_mod_8.reset_index(drop=True), data_mod_9.reset_index(drop=True), data_mod_10.reset_index(drop=True), data_mod_11.reset_index(drop=True),
                           data_mod_12.reset_index(drop=True), data_mod_13.reset_index(drop=True), data_mod_14.reset_index(drop=True), data_mod_15.reset_index(drop=True),
                           data_mod_16.reset_index(drop=True), data_mod_17.reset_index(drop=True), data_mod_18.reset_index(drop=True), data_mod_19.reset_index(drop=True),
                           data_mod_20.reset_index(drop=True), data_mod_21.reset_index(drop=True), data_mod_22.reset_index(drop=True), data_mod_23.reset_index(drop=True),
                           data_mod_24.reset_index(drop=True), data_mod_25.reset_index(drop=True), data_mod_26.reset_index(drop=True)], axis = 0, ignore_index = True)
    
    
    df_acc = pd.concat([df.iloc[:,5:].reset_index(drop=True), df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True)], axis = 0, ignore_index = True)
    
    mol_num = range(1,combined_df.shape[0]+1)
    combined_df['molecule'] = mol_num
    
    result_df = pd.concat([df_acc.reset_index(drop=True), combined_df.reset_index(drop=True)], axis = 1, ignore_index = True)
    result_df.columns = ["ax", "ay", "az", "px", "py", "pz", "molecule"]
    
    result_df = result_df[["molecule", "px", "py", "pz", "ax", "ay", "az"]]
    return(result_df)

# %%
def find_neighbors(t):
    df_gen = generate_data(t)
    
    k = 6
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='brute').fit(df_gen)
    distances, indices = nbrs.kneighbors(df_gen)
    
    return(k, df_gen, indices[:128], distances[:128])

# %%
def make_df(t):
    t_df = raw_data.loc[raw_data['time']==t]
    t_plus_1_df = raw_data.loc[raw_data['time']==t+1]
    
    acc_t_plus_1 = t_plus_1_df.iloc[:,5:]
    delta_position = pd.DataFrame(np.array(t_plus_1_df.iloc[:,2:5]) - np.array(t_df.iloc[:,2:5]), columns=['dlt_px','dlt_py','dlt_pz'])
    
    k, df_gen, indices, dist = find_neighbors(t)
    
    li = []
    for i in range(0,indices.shape[0]):
        rows = []
        for j in range(1,k):
            row = df_gen.loc[df_gen['molecule'] == (indices[i][j]+1)]
            row_acc = np.asarray(row.iloc[:,4:] / dist[i][j])
            rows.append(row_acc)
        
        li.append(np.array(rows).ravel())
    
    acc_df = t_df[['ax','ay','az']]
    neighbors_acc_df = pd.DataFrame(li)
    acc_t_plus_1.columns = ['next_ax','next_ay','next_az']
    
    df_made = pd.concat([acc_df.reset_index(drop=True), neighbors_acc_df.reset_index(drop=True), delta_position.reset_index(drop=True), 
                         acc_t_plus_1.reset_index(drop=True)], axis = 1)
    
    return(df_made)

# %%
#make whole dataset
final_data = make_df(0)

for t in range(1,499):
    df_part = make_df(t)
    final_data = pd.concat([final_data.reset_index(drop=True), df_part.reset_index(drop=True)], axis = 0, ignore_index=True)

# %%
final_data.tail()
# Out:
#              ax        ay        az         0         1         2         3  \
# 63867  0.671588 -1.506705  0.176252  0.513225 -0.028694  0.001673 -0.363138
# 63868 -1.849590 -2.051781 -0.247277  0.131856 -0.295818  0.034604  0.269963
# 63869  1.671373  1.482766 -3.824159  0.150628  0.016442 -0.164176 -0.167902
# 63870  1.584120  0.172918 -1.726600 -0.547084 -0.106578 -0.171183 -0.315204
# 63871 -3.039359 -0.592101 -0.951016  0.285141  0.031125 -0.310787 -0.280207
#
#               4         5         6    ...           11        12        13  \
# 63867 -0.402835 -0.048549  0.248637    ...    -0.185554 -0.385527 -0.075105
# 63868  0.029468 -0.294245 -0.460453    ...    -0.187238  0.245952 -0.191843
# 63869 -0.186257 -0.022447 -0.252680    ...    -0.453450  0.053636 -0.120333
# 63870 -0.349662 -0.042141  0.105410    ...     0.470291  0.245419 -0.191427
# 63871 -0.310838 -0.037462  0.080588    ...     0.022357 -0.074610 -0.018692
#
#              14   dlt_px   dlt_py   dlt_pz   next_ax   next_ay   next_az
# 63867 -0.120632 -0.00348 -0.00048 -0.00530  0.704895 -1.516483  0.229958
# 63868  0.043164 -0.01451 -0.00934 -0.00585 -1.671709 -1.961284 -0.276917
# 63869  0.014076  0.00302  0.00336  0.00954  1.726929  1.501112 -3.859814
# 63870  0.043070 -0.00169 -0.00566 -0.00570  1.718537  0.264688 -1.734184
# 63871 -0.168878 -0.01160  0.01002 -0.00902 -2.929070 -0.694252 -0.855092
#
# [5 rows x 24 columns]

# %%
##########################################################
################# save dataframe #########################
final_data.to_csv('./data/KNN_5_newVariable.csv', index = False)

# %%
#final_data = pd.read_csv('./data/KNN_5_newVariable.csv')

# %%
final_data.shape
# Out:
# (63872, 24)

# %%
exc_x_idx, = np.where(abs(final_data['dlt_px']) > 12)
exc_y_idx, = np.where(abs(final_data['dlt_py']) > 12)
exc_z_idx, = np.where(abs(final_data['dlt_pz']) > 12)

exc_idx = set(exc_x_idx) | set(exc_y_idx) | set(exc_z_idx)
final_data = final_data.loc[final_data.index.drop(list(exc_idx))]

# %%
x_train, x_test, y_train, y_test = train_test_split(final_data.iloc[:,0:18], 
                                                    final_data.iloc[:,18:],
                                                    test_size = 0.3, random_state = 10)

# %%
#model 1
model_1 = Sequential()

model_1.add(Dense(32, input_dim=18, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(32, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(32, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(6, activation='linear', kernel_initializer = 'glorot_normal', kernel_regularizer = regularizers.l2(0.01)))

# %%
model_1.compile(loss='mean_absolute_error', optimizer= 'rmsprop', metrics=['mae'])

early_stop = EarlyStopping(monitor='val_loss', patience=20, mode='min')
model_check_point = ModelCheckpoint('./model/KNN_5_newVariable.h5', monitor = 'val_loss', verbose=2, save_best_only=True)

callback_list = [model_check_point, early_stop]

# %%
hist_1 = model_1.fit(x_train.values, y_train.values, epochs=150, batch_size=64, validation_data=(x_test, y_test), callbacks = callback_list)
# Out:
# Train on 44639 samples, validate on 19132 samples
# Epoch 1/150
# 44639/44639 [==============================] - 3s 77us/step - loss: 0.8957 - mean_absolute_error: 0.3253 - val_loss: 0.4864 - val_mean_absolute_error: 0.3101
#
# Epoch 00001: val_loss improved from inf to 0.48639, saving model to ./model/KNN_5_newVariable.h5
# Epoch 2/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.3302 - mean_absolute_error: 0.2178 - val_loss: 0.2909 - val_mean_absolute_error: 0.2156
#
# Epoch 00002: val_loss improved from 0.48639 to 0.29090, saving model to ./model/KNN_5_newVariable.h5
# Epoch 3/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.2726 - mean_absolute_error: 0.2116 - val_loss: 0.2042 - val_mean_absolute_error: 0.1534
#
# Epoch 00003: val_loss improved from 0.29090 to 0.20424, saving model to ./model/KNN_5_newVariable.h5
# Epoch 4/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2545 - mean_absolute_error: 0.2090 - val_loss: 0.2037 - val_mean_absolute_error: 0.1621
#
# Epoch 00004: val_loss improved from 0.20424 to 0.20368, saving model to ./model/KNN_5_newVariable.h5
# Epoch 5/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.2435 - mean_absolute_error: 0.2042 - val_loss: 0.1521 - val_mean_absolute_error: 0.1154
#
# Epoch 00005: val_loss improved from 0.20368 to 0.15214, saving model to ./model/KNN_5_newVariable.h5
# Epoch 6/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.2352 - mean_absolute_error: 0.1995 - val_loss: 0.1703 - val_mean_absolute_error: 0.1359
#
# Epoch 00006: val_loss did not improve from 0.15214
# Epoch 7/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2330 - mean_absolute_error: 0.1998 - val_loss: 0.1422 - val_mean_absolute_error: 0.1102
#
# Epoch 00007: val_loss improved from 0.15214 to 0.14224, saving model to ./model/KNN_5_newVariable.h5
# Epoch 8/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2290 - mean_absolute_error: 0.1977 - val_loss: 0.1285 - val_mean_absolute_error: 0.0979
#
# Epoch 00008: val_loss improved from 0.14224 to 0.12851, saving model to ./model/KNN_5_newVariable.h5
# Epoch 9/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2228 - mean_absolute_error: 0.1931 - val_loss: 0.1351 - val_mean_absolute_error: 0.1057
#
# Epoch 00009: val_loss did not improve from 0.12851
# Epoch 10/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.2220 - mean_absolute_error: 0.1936 - val_loss: 0.1334 - val_mean_absolute_error: 0.1057
#
# Epoch 00010: val_loss did not improve from 0.12851
# Epoch 11/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2160 - mean_absolute_error: 0.1887 - val_loss: 0.1526 - val_mean_absolute_error: 0.1258
#
# Epoch 00011: val_loss did not improve from 0.12851
# Epoch 12/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2158 - mean_absolute_error: 0.1895 - val_loss: 0.1211 - val_mean_absolute_error: 0.0952
#
# Epoch 00012: val_loss improved from 0.12851 to 0.12107, saving model to ./model/KNN_5_newVariable.h5
# Epoch 13/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.2137 - mean_absolute_error: 0.1883 - val_loss: 0.1059 - val_mean_absolute_error: 0.0808
#
# Epoch 00013: val_loss improved from 0.12107 to 0.10591, saving model to ./model/KNN_5_newVariable.h5
# Epoch 14/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2155 - mean_absolute_error: 0.1909 - val_loss: 0.1128 - val_mean_absolute_error: 0.0888
#
# Epoch 00014: val_loss did not improve from 0.10591
# Epoch 15/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2142 - mean_absolute_error: 0.1904 - val_loss: 0.1295 - val_mean_absolute_error: 0.1062
#
# Epoch 00015: val_loss did not improve from 0.10591
# Epoch 16/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2103 - mean_absolute_error: 0.1873 - val_loss: 0.1391 - val_mean_absolute_error: 0.1162
#
# Epoch 00016: val_loss did not improve from 0.10591
# Epoch 17/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2117 - mean_absolute_error: 0.1893 - val_loss: 0.1374 - val_mean_absolute_error: 0.1152
#
# Epoch 00017: val_loss did not improve from 0.10591
# Epoch 18/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.2081 - mean_absolute_error: 0.1864 - val_loss: 0.1397 - val_mean_absolute_error: 0.1184
#
# Epoch 00018: val_loss did not improve from 0.10591
# Epoch 19/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.2080 - mean_absolute_error: 0.1869 - val_loss: 0.1413 - val_mean_absolute_error: 0.1204
#
# Epoch 00019: val_loss did not improve from 0.10591
# Epoch 20/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2025 - mean_absolute_error: 0.1817 - val_loss: 0.1251 - val_mean_absolute_error: 0.1043
#
# Epoch 00020: val_loss did not improve from 0.10591
# Epoch 21/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2068 - mean_absolute_error: 0.1868 - val_loss: 0.1405 - val_mean_absolute_error: 0.1211
#
# Epoch 00021: val_loss did not improve from 0.10591
# Epoch 22/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2067 - mean_absolute_error: 0.1873 - val_loss: 0.1096 - val_mean_absolute_error: 0.0906
#
# Epoch 00022: val_loss did not improve from 0.10591
# Epoch 23/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2029 - mean_absolute_error: 0.1841 - val_loss: 0.1366 - val_mean_absolute_error: 0.1188
#
# Epoch 00023: val_loss did not improve from 0.10591
# Epoch 24/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.2008 - mean_absolute_error: 0.1826 - val_loss: 0.1249 - val_mean_absolute_error: 0.1068
#
# Epoch 00024: val_loss did not improve from 0.10591
# Epoch 25/150
# 44639/44639 [==============================] - 2s 50us/step - loss: 0.2050 - mean_absolute_error: 0.1870 - val_loss: 0.1673 - val_mean_absolute_error: 0.1503
#
# Epoch 00025: val_loss did not improve from 0.10591
# Epoch 26/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.2024 - mean_absolute_error: 0.1849 - val_loss: 0.0928 - val_mean_absolute_error: 0.0751
#
# Epoch 00026: val_loss improved from 0.10591 to 0.09280, saving model to ./model/KNN_5_newVariable.h5
# Epoch 27/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.2009 - mean_absolute_error: 0.1837 - val_loss: 0.1169 - val_mean_absolute_error: 0.0997
#
# Epoch 00027: val_loss did not improve from 0.09280
# Epoch 28/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2017 - mean_absolute_error: 0.1846 - val_loss: 0.1182 - val_mean_absolute_error: 0.1011
#
# Epoch 00028: val_loss did not improve from 0.09280
# Epoch 29/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2010 - mean_absolute_error: 0.1841 - val_loss: 0.1176 - val_mean_absolute_error: 0.1012
#
# Epoch 00029: val_loss did not improve from 0.09280
# Epoch 30/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.2008 - mean_absolute_error: 0.1842 - val_loss: 0.1218 - val_mean_absolute_error: 0.1054
#
# Epoch 00030: val_loss did not improve from 0.09280
# Epoch 31/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1976 - mean_absolute_error: 0.1811 - val_loss: 0.1145 - val_mean_absolute_error: 0.0980
#
# Epoch 00031: val_loss did not improve from 0.09280
# Epoch 32/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1974 - mean_absolute_error: 0.1810 - val_loss: 0.0997 - val_mean_absolute_error: 0.0835
#
# Epoch 00032: val_loss did not improve from 0.09280
# Epoch 33/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.2015 - mean_absolute_error: 0.1855 - val_loss: 0.1414 - val_mean_absolute_error: 0.1257
#
# Epoch 00033: val_loss did not improve from 0.09280
# Epoch 34/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.1990 - mean_absolute_error: 0.1831 - val_loss: 0.1001 - val_mean_absolute_error: 0.0839
#
# Epoch 00034: val_loss did not improve from 0.09280
# Epoch 35/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1954 - mean_absolute_error: 0.1797 - val_loss: 0.1264 - val_mean_absolute_error: 0.1109
#
# Epoch 00035: val_loss did not improve from 0.09280
# Epoch 36/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1956 - mean_absolute_error: 0.1801 - val_loss: 0.1176 - val_mean_absolute_error: 0.1016
#
# Epoch 00036: val_loss did not improve from 0.09280
# Epoch 37/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1978 - mean_absolute_error: 0.1825 - val_loss: 0.0871 - val_mean_absolute_error: 0.0717
#
# Epoch 00037: val_loss improved from 0.09280 to 0.08713, saving model to ./model/KNN_5_newVariable.h5
# Epoch 38/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1949 - mean_absolute_error: 0.1798 - val_loss: 0.0969 - val_mean_absolute_error: 0.0816
#
# Epoch 00038: val_loss did not improve from 0.08713
# Epoch 39/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1922 - mean_absolute_error: 0.1772 - val_loss: 0.1085 - val_mean_absolute_error: 0.0936
#
# Epoch 00039: val_loss did not improve from 0.08713
# Epoch 40/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1955 - mean_absolute_error: 0.1807 - val_loss: 0.1119 - val_mean_absolute_error: 0.0974
#
# Epoch 00040: val_loss did not improve from 0.08713
# Epoch 41/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1951 - mean_absolute_error: 0.1804 - val_loss: 0.1004 - val_mean_absolute_error: 0.0857
#
# Epoch 00041: val_loss did not improve from 0.08713
# Epoch 42/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1943 - mean_absolute_error: 0.1798 - val_loss: 0.0990 - val_mean_absolute_error: 0.0846
#
# Epoch 00042: val_loss did not improve from 0.08713
# Epoch 43/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1909 - mean_absolute_error: 0.1765 - val_loss: 0.1196 - val_mean_absolute_error: 0.1053
#
# Epoch 00043: val_loss did not improve from 0.08713
# Epoch 44/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1925 - mean_absolute_error: 0.1783 - val_loss: 0.1004 - val_mean_absolute_error: 0.0859
#
# Epoch 00044: val_loss did not improve from 0.08713
# Epoch 45/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1929 - mean_absolute_error: 0.1788 - val_loss: 0.1106 - val_mean_absolute_error: 0.0964
#
# Epoch 00045: val_loss did not improve from 0.08713
# Epoch 46/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1915 - mean_absolute_error: 0.1775 - val_loss: 0.1056 - val_mean_absolute_error: 0.0918
#
# Epoch 00046: val_loss did not improve from 0.08713
# Epoch 47/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1933 - mean_absolute_error: 0.1795 - val_loss: 0.0813 - val_mean_absolute_error: 0.0675
#
# Epoch 00047: val_loss improved from 0.08713 to 0.08134, saving model to ./model/KNN_5_newVariable.h5
# Epoch 48/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1938 - mean_absolute_error: 0.1803 - val_loss: 0.1013 - val_mean_absolute_error: 0.0876
#
# Epoch 00048: val_loss did not improve from 0.08134
# Epoch 49/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1951 - mean_absolute_error: 0.1816 - val_loss: 0.0902 - val_mean_absolute_error: 0.0766
#
# Epoch 00049: val_loss did not improve from 0.08134
# Epoch 50/150
# 44639/44639 [==============================] - 2s 50us/step - loss: 0.1953 - mean_absolute_error: 0.1819 - val_loss: 0.0902 - val_mean_absolute_error: 0.0769
#
# Epoch 00050: val_loss did not improve from 0.08134
# Epoch 51/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.1928 - mean_absolute_error: 0.1796 - val_loss: 0.1063 - val_mean_absolute_error: 0.0931
#
# Epoch 00051: val_loss did not improve from 0.08134
# Epoch 52/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1927 - mean_absolute_error: 0.1794 - val_loss: 0.1037 - val_mean_absolute_error: 0.0908
#
# Epoch 00052: val_loss did not improve from 0.08134
# Epoch 53/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1943 - mean_absolute_error: 0.1812 - val_loss: 0.1019 - val_mean_absolute_error: 0.0887
#
# Epoch 00053: val_loss did not improve from 0.08134
# Epoch 54/150
# 44639/44639 [==============================] - 2s 49us/step - loss: 0.1880 - mean_absolute_error: 0.1749 - val_loss: 0.0890 - val_mean_absolute_error: 0.0757
#
# Epoch 00054: val_loss did not improve from 0.08134
# Epoch 55/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1925 - mean_absolute_error: 0.1795 - val_loss: 0.1022 - val_mean_absolute_error: 0.0893
#
# Epoch 00055: val_loss did not improve from 0.08134
# Epoch 56/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1924 - mean_absolute_error: 0.1795 - val_loss: 0.0954 - val_mean_absolute_error: 0.0824
#
# Epoch 00056: val_loss did not improve from 0.08134
# Epoch 57/150
# 44639/44639 [==============================] - 2s 50us/step - loss: 0.1922 - mean_absolute_error: 0.1794 - val_loss: 0.0880 - val_mean_absolute_error: 0.0750
#
# Epoch 00057: val_loss did not improve from 0.08134
# Epoch 58/150
# 44639/44639 [==============================] - 2s 50us/step - loss: 0.1917 - mean_absolute_error: 0.1789 - val_loss: 0.1001 - val_mean_absolute_error: 0.0872
#
# Epoch 00058: val_loss did not improve from 0.08134
# Epoch 59/150
# 44639/44639 [==============================] - 2s 50us/step - loss: 0.1901 - mean_absolute_error: 0.1774 - val_loss: 0.1344 - val_mean_absolute_error: 0.1218
#
# Epoch 00059: val_loss did not improve from 0.08134
# Epoch 60/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1934 - mean_absolute_error: 0.1807 - val_loss: 0.0965 - val_mean_absolute_error: 0.0839
#
# Epoch 00060: val_loss did not improve from 0.08134
# Epoch 61/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1979 - mean_absolute_error: 0.1853 - val_loss: 0.1373 - val_mean_absolute_error: 0.1248
#
# Epoch 00061: val_loss did not improve from 0.08134
# Epoch 62/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1926 - mean_absolute_error: 0.1801 - val_loss: 0.1053 - val_mean_absolute_error: 0.0930
#
# Epoch 00062: val_loss did not improve from 0.08134
# Epoch 63/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1920 - mean_absolute_error: 0.1796 - val_loss: 0.0776 - val_mean_absolute_error: 0.0650
#
# Epoch 00063: val_loss improved from 0.08134 to 0.07756, saving model to ./model/KNN_5_newVariable.h5
# Epoch 64/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1930 - mean_absolute_error: 0.1806 - val_loss: 0.1349 - val_mean_absolute_error: 0.1226
#
# Epoch 00064: val_loss did not improve from 0.07756
# Epoch 65/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1903 - mean_absolute_error: 0.1780 - val_loss: 0.1010 - val_mean_absolute_error: 0.0887
#
# Epoch 00065: val_loss did not improve from 0.07756
# Epoch 66/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1898 - mean_absolute_error: 0.1773 - val_loss: 0.0894 - val_mean_absolute_error: 0.0767
#
# Epoch 00066: val_loss did not improve from 0.07756
# Epoch 67/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1922 - mean_absolute_error: 0.1799 - val_loss: 0.1119 - val_mean_absolute_error: 0.0996
#
# Epoch 00067: val_loss did not improve from 0.07756
# Epoch 68/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1925 - mean_absolute_error: 0.1803 - val_loss: 0.0913 - val_mean_absolute_error: 0.0791
#
# Epoch 00068: val_loss did not improve from 0.07756
# Epoch 69/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1880 - mean_absolute_error: 0.1758 - val_loss: 0.1229 - val_mean_absolute_error: 0.1109
#
# Epoch 00069: val_loss did not improve from 0.07756
# Epoch 70/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1922 - mean_absolute_error: 0.1800 - val_loss: 0.0818 - val_mean_absolute_error: 0.0697
#
# Epoch 00070: val_loss did not improve from 0.07756
# Epoch 71/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1894 - mean_absolute_error: 0.1774 - val_loss: 0.0899 - val_mean_absolute_error: 0.0779
#
# Epoch 00071: val_loss did not improve from 0.07756
# Epoch 72/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1911 - mean_absolute_error: 0.1791 - val_loss: 0.1029 - val_mean_absolute_error: 0.0910
#
# Epoch 00072: val_loss did not improve from 0.07756
# Epoch 73/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1905 - mean_absolute_error: 0.1786 - val_loss: 0.0875 - val_mean_absolute_error: 0.0755
#
# Epoch 00073: val_loss did not improve from 0.07756
# Epoch 74/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1926 - mean_absolute_error: 0.1807 - val_loss: 0.1024 - val_mean_absolute_error: 0.0907
#
# Epoch 00074: val_loss did not improve from 0.07756
# Epoch 75/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1892 - mean_absolute_error: 0.1774 - val_loss: 0.0947 - val_mean_absolute_error: 0.0830
#
# Epoch 00075: val_loss did not improve from 0.07756
# Epoch 76/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1882 - mean_absolute_error: 0.1764 - val_loss: 0.1066 - val_mean_absolute_error: 0.0952
#
# Epoch 00076: val_loss did not improve from 0.07756
# Epoch 77/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1917 - mean_absolute_error: 0.1800 - val_loss: 0.1296 - val_mean_absolute_error: 0.1181
#
# Epoch 00077: val_loss did not improve from 0.07756
# Epoch 78/150
# 44639/44639 [==============================] - 2s 48us/step - loss: 0.1891 - mean_absolute_error: 0.1774 - val_loss: 0.0962 - val_mean_absolute_error: 0.0846
#
# Epoch 00078: val_loss did not improve from 0.07756
# Epoch 79/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1871 - mean_absolute_error: 0.1755 - val_loss: 0.1000 - val_mean_absolute_error: 0.0883
#
# Epoch 00079: val_loss did not improve from 0.07756
# Epoch 80/150
# 44639/44639 [==============================] - 2s 46us/step - loss: 0.1925 - mean_absolute_error: 0.1809 - val_loss: 0.1131 - val_mean_absolute_error: 0.1017
#
# Epoch 00080: val_loss did not improve from 0.07756
# Epoch 81/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1908 - mean_absolute_error: 0.1793 - val_loss: 0.1040 - val_mean_absolute_error: 0.0924
#
# Epoch 00081: val_loss did not improve from 0.07756
# Epoch 82/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1898 - mean_absolute_error: 0.1785 - val_loss: 0.0930 - val_mean_absolute_error: 0.0819
#
# Epoch 00082: val_loss did not improve from 0.07756
# Epoch 83/150
# 44639/44639 [==============================] - 2s 47us/step - loss: 0.1892 - mean_absolute_error: 0.1779 - val_loss: 0.1346 - val_mean_absolute_error: 0.1236
#
# Epoch 00083: val_loss did not improve from 0.07756

# %%
# plot history
plt.plot(hist_1.history['loss'], label='train')
plt.plot(hist_1.history['val_loss'], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model = load_model('./model/KNN_5_newVariable.h5')

# %%
y_pred = pd.DataFrame(model.predict(x_test))

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae_metric = mean_absolute_error(y_test, y_pred)
r2_error = r2_score(y_test.values, y_pred)

# %%
print("MSE:", mse)
print("RMSE: ", rmse)
print("MAE: ", mae_metric)
print("R2_Score:", r2_error)
# Out:
# MSE: 0.01280739154952369
# RMSE:  0.11316974661774096
# MAE:  0.0650470076023284
# R2_Score: -2.660372870441193

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(3,3,1)
ax2 = fig.add_subplot(3,3,2)
ax3 = fig.add_subplot(3,3,3)
ax4 = fig.add_subplot(3,3,4)
ax5 = fig.add_subplot(3,3,5)
ax6 = fig.add_subplot(3,3,6)

ax1.scatter(y_test.values[:,0], y_pred.iloc[:,0], s= 2)
ax1.set_xlabel('dlt_x_real')
ax1.set_ylabel('dlt_x_pred')
#ax1.set_xlim((-2.5, 2.5))
#ax1.set_ylim((-2.5, 2.5))
ax2.scatter(y_test.values[:,1], y_pred.iloc[:,1], s= 2)
ax2.set_xlabel('dlt_y_real')
ax2.set_ylabel('dlt_y_pred')
#ax2.set_xlim((-2.5, 2.5))
#ax2.set_ylim((-2.5, 2.5))
ax3.scatter(y_test.values[:,2], y_pred.iloc[:,2], s= 2)
ax3.set_xlabel('dlt_z_real')
ax3.set_ylabel('dlt_z_pred')
#ax3.set_xlim((-2.5, 2.5))
#ax3.set_ylim((-2.5, 2.5))
ax4.scatter(y_test.values[:,3], y_pred.iloc[:,3], s= 2)
ax4.set_xlabel('ax_real')
ax4.set_ylabel('ax_pred')
#ax4.set_xlim((-2.5, 2.5))
#ax4.set_ylim((-2.5, 2.5))
ax5.scatter(y_test.values[:,4], y_pred.iloc[:,4], s= 2)
ax5.set_xlabel('ay_real')
ax5.set_ylabel('ay_pred')
#ax5.set_xlim((-2.5, 2.5))
#ax5.set_ylim((-2.5, 2.5))
ax6.scatter(y_test.values[:,5], y_pred.iloc[:,5], s= 2)
ax6.set_xlabel('az_real')
ax6.set_ylabel('az_pred')
#ax6.set_xlim((-2.5, 2.5))
#ax6.set_ylim((-2.5, 2.5))

plt.subplots_adjust(wspace = 1, hspace = 0.5)
plt.show()

# %%
#cross validation

kfold = KFold(n_splits=20, shuffle=True, random_state = 500)
data = final_data
X = final_data.iloc[:,0:18]
Y = final_data.iloc[:,18:]

cv_rmse = []
cv_mae = []
cv_r2 = []

for train, test in kfold.split(X, Y):
    
    # evaluate the model
    pred = model.predict(X.iloc[test,:])
    
    rmse = np.sqrt(mean_squared_error(Y.iloc[test,:], pred))
    mae = mean_absolute_error(Y.iloc[test,:], pred)
    r2 = r2_score(Y.iloc[test,:], pred)
    
    cv_rmse.append(rmse)
    cv_mae.append(mae)
    cv_r2.append(r2)

# %%
print(np.mean(cv_rmse))
print(np.std(cv_rmse))
print('\n')

print(np.mean(cv_mae))
print(np.std(cv_mae))
print('\n')

print(np.mean(cv_r2))
print(np.std(cv_r2))
# Out:
# 0.11296077608085345
# 0.0015281441462226648
#
#
# 0.06503888987388778
# 0.000632831850318109
#
#
# -2.6316363170475663
# 0.11012332191774545

# %%
test_data.head()
# Out:
#        time  molecule       px        py        pz        ax        ay  \
# 64128   501         1  0.64827  11.02011  11.37010  0.696679 -1.685899
# 64129   501         2  0.04815   1.44542   1.20463  3.432097  1.136779
# 64130   501         3  0.02262  12.88548   3.64838 -0.730071 -0.108348
# 64131   501         4  3.34930   2.46952   7.42830  0.574373 -5.050313
# 64132   501         5  1.30078   0.89000   5.59690  3.567397 -3.225998
#
#              az
# 64128  3.330733
# 64129  5.471035
# 64130 -1.569026
# 64131 -6.268711
# 64132  0.222102

# %%
test_data = make_df(501)

for t in range(502,999):
    df_part = make_df(t)
    test_data = pd.concat([test_data.reset_index(drop=True), df_part.reset_index(drop=True)], axis = 0, ignore_index=True)

# %%
predicted = model.predict()
