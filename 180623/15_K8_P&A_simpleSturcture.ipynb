# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import scale, StandardScaler

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Input, concatenate
from keras.layers.normalization import BatchNormalization
from keras.initializers import Initializer
from keras import regularizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
raw_data = pd.read_csv('./data/ordered_molecules.csv')

# %%
raw_data.tail()
# Out:
#         time  molecule        px        py        pz        ax        ay  \
# 255995  1999       124  10.61230   9.20293   8.07598 -1.025038  3.645025
# 255996  1999       125  12.28148   7.63805   8.68123  3.634594 -3.766582
# 255997  1999       126   6.03300  12.81292   6.05135  2.307742  5.650190
# 255998  1999       127   9.50306  10.44102   9.99912  1.395564 -1.232665
# 255999  1999       128  12.01283  11.18948  11.90577 -0.730089 -1.992210
#
#               az
# 255995 -1.280867
# 255996 -2.338953
# 255997  5.404642
# 255998 -0.779073
# 255999 -0.056095

# %%
def generate_data(t):
    df = raw_data.loc[raw_data['time'] == t]
    
    px_plus = df.iloc[:,2] + 12.9168567587204
    px_origin = df.iloc[:,2]
    px_minus = df.iloc[:,2] - 12.9168567587204
    
    py_plus = df.iloc[:,3] + 12.9168567587204
    py_origin = df.iloc[:,3]
    py_minus = df.iloc[:,3] - 12.9168567587204
    
    pz_plus = df.iloc[:,4] + 12.9168567587204
    pz_origin = df.iloc[:,4]
    pz_minus = df.iloc[:,4] - 12.9168567587204
    
    #plus
    data_mod_1 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_2 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_3 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_4 = pd.concat((px_plus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_5 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_6 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_7 = pd.concat((px_plus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    #minus
    data_mod_8 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_9 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_10 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_11 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_12 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_13 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_14 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    #plus + minus
    data_mod_15 = pd.concat((px_origin.reset_index(drop=True), py_plus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_16 = pd.concat((px_origin.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_17 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    data_mod_18 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    
    data_mod_19 = pd.concat((px_plus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_20 = pd.concat((px_minus.reset_index(drop=True), py_origin.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    #3
    data_mod_21 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_22 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_23 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    data_mod_24 = pd.concat((px_minus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_plus.reset_index(drop=True)), axis = 1)
    
    data_mod_25 = pd.concat((px_plus.reset_index(drop=True), py_minus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    data_mod_26 = pd.concat((px_minus.reset_index(drop=True), py_plus.reset_index(drop=True), pz_minus.reset_index(drop=True)), axis = 1)
    
    data_mod_27 = pd.concat((px_origin.reset_index(drop=True), py_origin.reset_index(drop=True), pz_origin.reset_index(drop=True)), axis = 1)
    
    combined_df = pd.concat([data_mod_27.reset_index(drop=True), data_mod_1.reset_index(drop=True), data_mod_2.reset_index(drop=True), data_mod_3.reset_index(drop=True), 
                           data_mod_4.reset_index(drop=True), data_mod_5.reset_index(drop=True), data_mod_6.reset_index(drop=True), data_mod_7.reset_index(drop=True), 
                           data_mod_8.reset_index(drop=True), data_mod_9.reset_index(drop=True), data_mod_10.reset_index(drop=True), data_mod_11.reset_index(drop=True),
                           data_mod_12.reset_index(drop=True), data_mod_13.reset_index(drop=True), data_mod_14.reset_index(drop=True), data_mod_15.reset_index(drop=True),
                           data_mod_16.reset_index(drop=True), data_mod_17.reset_index(drop=True), data_mod_18.reset_index(drop=True), data_mod_19.reset_index(drop=True),
                           data_mod_20.reset_index(drop=True), data_mod_21.reset_index(drop=True), data_mod_22.reset_index(drop=True), data_mod_23.reset_index(drop=True),
                           data_mod_24.reset_index(drop=True), data_mod_25.reset_index(drop=True), data_mod_26.reset_index(drop=True)], axis = 0, ignore_index = True)
    
    
    df_acc = pd.concat([df.iloc[:,5:].reset_index(drop=True), df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),
                        df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True),df.iloc[:,5:].reset_index(drop=True)], axis = 0, ignore_index = True)
    
    mol_num = range(1,combined_df.shape[0]+1)
    combined_df['molecule'] = mol_num
    
    result_df = pd.concat([df_acc.reset_index(drop=True), combined_df.reset_index(drop=True)], axis = 1, ignore_index = True)
    result_df.columns = ["ax", "ay", "az", "px", "py", "pz", "molecule"]
    
    result_df = result_df[["molecule", "px", "py", "pz", "ax", "ay", "az"]]
    return(result_df)

# %%
generate_data(0).tail()
# Out:
#       molecule        px         py        pz        ax        ay        az
# 3451      3452 -2.282917  23.957887 -8.189287  2.826494  0.120729  3.561412
# 3452      3453 -3.424287  22.244557 -6.353907  0.540960  2.726446 -0.040251
# 3453      3454 -1.724537  24.117957 -5.084297  0.363945 -0.033185  0.824533
# 3454      3455 -2.970927  22.454267 -3.323367 -0.612577  1.925591 -0.319277
# 3455      3456 -1.005977  24.060017 -1.581507 -3.718706  0.246769 -1.344216

# %%
def find_neighbors(t):
    df_gen = generate_data(t)
    
    k = 9
    nbrs = NearestNeighbors(n_neighbors=k, algorithm='brute').fit(df_gen)
    distances, indices = nbrs.kneighbors(df_gen)
    
    return(k, df_gen, indices[:128], distances[:128])

# %%
def make_df(t):
    t_df = raw_data.loc[raw_data['time']==t]
    t_plus_1_df = raw_data.loc[raw_data['time']==t+1]
    
    acc_t_plus_1 = t_plus_1_df.iloc[:,5:]
    delta_position = pd.DataFrame(np.array(t_plus_1_df.iloc[:,2:5]) - np.array(t_df.iloc[:,2:5]), columns=['dlt_px','dlt_py','dlt_pz'])
    
    k, df_gen, indices, dist = find_neighbors(t)
    
    li = []
    for i in range(0,indices.shape[0]):
        rows = []
        for j in range(1,k):
            row = df_gen.loc[df_gen['molecule'] == (indices[i][j]+1)]
            row_rp = row.iloc[:,1:4] - t_df.iloc[i,2:5]
            row_acc = pd.DataFrame(np.array(row.iloc[:,4:]) / dist[i][j])
            
            row_combined = np.array(pd.concat([row_rp.reset_index(drop=True), row_acc.reset_index(drop=True)], axis = 1))
            rows.append(row_combined)
        
        li.append(np.array(rows).ravel())
    
    acc_df = t_df[['time','ax','ay','az']]
    neighbors_df = pd.DataFrame(li)
    acc_t_plus_1.columns = ['next_ax','next_ay','next_az']
    
    df_made = pd.concat([acc_df.reset_index(drop=True), neighbors_df.reset_index(drop=True), 
                         delta_position.reset_index(drop=True), acc_t_plus_1.reset_index(drop=True)], axis = 1)
    
    return(df_made)

# %%
make_df(8)

# %%
#make whole dataset
final_data = make_df(1)

for t in range(2,1999):
    df_part = make_df(t)
    final_data = pd.concat([final_data, df_part], axis = 0, ignore_index=True)

# %%
plt.plot(final_data['dlt_px'])

# %%
##########################################################
################# save dataframe #########################
#final_data.to_csv('./data/KNN_8_P_A.csv', index = False)

# %% [markdown]
# # **Read Data**

# %% [markdown]
# ## Neural Network Sturucture : 54-64-64-64-6

# %%
final_data = pd.read_csv('./data/KNN_8_P_A.csv')

# %%
final_data.tail()
# Out:
#         time        ax        ay        az        0        1        2  \
# 255867  1998 -1.117306  3.729599 -1.309010 -1.11728  1.23271  1.93306
# 255868  1998  3.562240 -3.790684 -2.208148 -2.78356  2.79630  1.33114
# 255869  1998  1.966739  5.790018  5.545910  4.58574 -3.60994  2.02446
# 255870  1998  1.619934 -1.090169 -0.924991  2.50430  0.75071  1.88872
# 255871  1998 -0.597181 -1.916267  0.042068 -2.50430 -0.75071 -1.88872
#
#                3         4         5    ...          44        45        46  \
# 255867  0.237879 -0.160086 -0.135830    ...    -7.90545 -0.505162 -0.084367
# 255868  0.277607 -0.186822 -0.158515    ...    -7.15338  0.396960 -0.242948
# 255869 -0.110142  0.367657 -0.129040    ...    -0.80648 -0.077386  0.048067
# 255870 -0.141009 -0.452479  0.009933    ...    -3.95752  0.176852  0.520645
# 255871  0.382507 -0.257416 -0.218414    ...    -7.81960 -0.494961  0.294826
#
#               47   dlt_px   dlt_py   dlt_pz   next_ax   next_ay   next_az
# 255867 -0.224528 -0.00663  0.00362  0.00284 -1.025038  3.645025 -1.280867
# 255868  0.197936 -0.00373  0.00233  0.00617  3.634594 -3.766582 -2.338953
# 255869  0.211089 -0.00019  0.00367  0.00267  2.307742  5.650190  5.404642
# 255870  0.498695  0.00141  0.00900 -0.00708  1.395564 -1.232665 -0.779073
# 255871 -0.059732  0.00688  0.00675  0.01085 -0.730089 -1.992210 -0.056095
#
# [5 rows x 58 columns]

# %%
final_data_new = final_data.loc[final_data['time'] >= 1]

# %%
dlt_for_x = final_data.loc[final_data['time'] <= 1997][['dlt_px','dlt_py','dlt_pz']]
dlt_for_x.columns = ['past_dlt_px','past_dlt_py','past_dlt_pz']

# %%
final_data_new.insert(loc = 1, column = 'past_dlt_px', value = np.array(dlt_for_x.iloc[:,0]))
final_data_new.insert(loc = 2, column = 'past_dlt_py', value = np.array(dlt_for_x.iloc[:,1]))
final_data_new.insert(loc = 3, column = 'past_dlt_pz', value = np.array(dlt_for_x.iloc[:,2]))

final_data_new = final_data_new.reset_index(drop=True)

# %%
final_data_new.tail()
# Out:
#         time  past_dlt_px  past_dlt_py  past_dlt_pz        ax        ay  \
# 255739  1998     -0.00659      0.00343      0.00291 -1.117306  3.729599
# 255740  1998     -0.00393      0.00253      0.00630  3.562240 -3.790684
# 255741  1998     -0.00030      0.00338      0.00239  1.966739  5.790018
# 255742  1998      0.00134      0.00907     -0.00705  1.619934 -1.090169
# 255743  1998      0.00694      0.00686      0.01088 -0.597181 -1.916267
#
#               az        0        1        2    ...          44        45  \
# 255739 -1.309010 -1.11728  1.23271  1.93306    ...    -7.90545 -0.505162
# 255740 -2.208148 -2.78356  2.79630  1.33114    ...    -7.15338  0.396960
# 255741  5.545910  4.58574 -3.60994  2.02446    ...    -0.80648 -0.077386
# 255742 -0.924991  2.50430  0.75071  1.88872    ...    -3.95752  0.176852
# 255743  0.042068 -2.50430 -0.75071 -1.88872    ...    -7.81960 -0.494961
#
#               46        47   dlt_px   dlt_py   dlt_pz   next_ax   next_ay  \
# 255739 -0.084367 -0.224528 -0.00663  0.00362  0.00284 -1.025038  3.645025
# 255740 -0.242948  0.197936 -0.00373  0.00233  0.00617  3.634594 -3.766582
# 255741  0.048067  0.211089 -0.00019  0.00367  0.00267  2.307742  5.650190
# 255742  0.520645  0.498695  0.00141  0.00900 -0.00708  1.395564 -1.232665
# 255743  0.294826 -0.059732  0.00688  0.00675  0.01085 -0.730089 -1.992210
#
#          next_az
# 255739 -1.280867
# 255740 -2.338953
# 255741  5.404642
# 255742 -0.779073
# 255743 -0.056095
#
# [5 rows x 61 columns]

# %%
exc_x_idx_past, = np.where(abs(final_data_new['past_dlt_px']) > 12)
exc_y_idx_past, = np.where(abs(final_data_new['past_dlt_py']) > 12)
exc_z_idx_past, = np.where(abs(final_data_new['past_dlt_pz']) > 12)

exc_x_idx, = np.where(abs(final_data_new['dlt_px']) > 12)
exc_y_idx, = np.where(abs(final_data_new['dlt_py']) > 12)
exc_z_idx, = np.where(abs(final_data_new['dlt_pz']) > 12)

exc_idx = set(exc_x_idx) | set(exc_y_idx) | set(exc_z_idx) | set(exc_x_idx_past) | set(exc_y_idx_past) | set(exc_z_idx_past)

final_data_modi = final_data_new.loc[final_data_new.index.drop(list(exc_idx))].reset_index(drop=True)

# %%
x_train = final_data_modi.loc[(final_data_modi['time'] >= 1) & (final_data_modi['time'] <= 1399)].iloc[:,1:55]
y_train = final_data_modi.loc[(final_data_modi['time'] >= 1) & (final_data_modi['time'] <= 1399)].iloc[:,55:]

x_test = final_data_modi.loc[(final_data_modi['time'] >= 1400) & (final_data_modi['time'] <= 1998)].iloc[:,1:55]
y_test = final_data_modi.loc[(final_data_modi['time'] >= 1400) & (final_data_modi['time'] <= 1998)].iloc[:,55:]

# %%
x_scaler = StandardScaler()
y_scaler = StandardScaler()

x_scaler.fit(x_train)
y_scaler.fit(y_train)

#Regularization
x_train_scaled = pd.DataFrame(x_scaler.transform(x_train))
y_train_scaled = pd.DataFrame(y_scaler.transform(y_train), columns=['dlt_x','dlt_y','dlt_z','ax_next','ay_next','az_next'])

x_test_scaled = pd.DataFrame(x_scaler.transform(x_test))
y_test_scaled = pd.DataFrame(y_scaler.transform(y_test), columns=['dlt_x','dlt_y','dlt_z','ax_next','ay_next','az_next'])

# %%
y_train_scaled.tail()
# Out:
#            dlt_x     dlt_y     dlt_z   ax_next   ay_next   az_next
# 178598 -0.168798 -1.786967  0.603659  0.162429  1.802063  1.613394
# 178599  0.397643 -0.339438 -1.024236 -1.337050  1.978555  0.152288
# 178600  2.139187 -0.078920 -2.254868 -0.289702 -0.063731 -0.475223
# 178601  2.206034  0.227464  0.598362 -0.193671  0.875774 -0.927754
# 178602 -0.341194 -0.148636 -0.692300  0.363752 -1.480910 -0.816797

# %%
model_1 = Sequential()

model_1.add(Dense(64, input_dim=54, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(64, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(64, activation='relu', kernel_initializer = 'he_normal', kernel_regularizer = regularizers.l2(0.01)))
model_1.add(BatchNormalization())

model_1.add(Dense(6, activation='linear', kernel_initializer = 'glorot_normal', kernel_regularizer = regularizers.l2(0.01)))

# %%
model_1.compile(loss='mean_squared_error', optimizer= 'adam', metrics=['mse'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, mode='min')
model_check_point = ModelCheckpoint('./model/K8_PA_simpleStructure.h5', monitor = 'val_loss', verbose=2, save_best_only=True)

callback_list = [model_check_point, early_stop]

# %%
hist_1 = model_1.fit(x_train_scaled, y_train_scaled, epochs=150, batch_size=64, validation_data=(x_test_scaled, y_test_scaled), callbacks = callback_list)
# Out:
# Train on 178603 samples, validate on 76489 samples
# Epoch 1/150
# 178603/178603 [==============================] - 11s 63us/step - loss: 0.4662 - mean_squared_error: 0.1064 - val_loss: 0.0350 - val_mean_squared_error: 0.0177
#
# Epoch 00001: val_loss improved from inf to 0.03498, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 2/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0533 - mean_squared_error: 0.0375 - val_loss: 0.0368 - val_mean_squared_error: 0.0226
#
# Epoch 00002: val_loss did not improve from 0.03498
# Epoch 3/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0440 - mean_squared_error: 0.0328 - val_loss: 0.0184 - val_mean_squared_error: 0.0096
#
# Epoch 00003: val_loss improved from 0.03498 to 0.01840, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 4/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0364 - mean_squared_error: 0.0286 - val_loss: 0.0210 - val_mean_squared_error: 0.0140
#
# Epoch 00004: val_loss did not improve from 0.01840
# Epoch 5/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0346 - mean_squared_error: 0.0280 - val_loss: 0.0163 - val_mean_squared_error: 0.0100
#
# Epoch 00005: val_loss improved from 0.01840 to 0.01626, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 6/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0338 - mean_squared_error: 0.0279 - val_loss: 0.0296 - val_mean_squared_error: 0.0241
#
# Epoch 00006: val_loss did not improve from 0.01626
# Epoch 7/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0337 - mean_squared_error: 0.0281 - val_loss: 0.0161 - val_mean_squared_error: 0.0107
#
# Epoch 00007: val_loss improved from 0.01626 to 0.01615, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 8/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0336 - mean_squared_error: 0.0282 - val_loss: 0.0277 - val_mean_squared_error: 0.0225
#
# Epoch 00008: val_loss did not improve from 0.01615
# Epoch 9/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0328 - mean_squared_error: 0.0277 - val_loss: 0.0198 - val_mean_squared_error: 0.0148
#
# Epoch 00009: val_loss did not improve from 0.01615
# Epoch 10/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0326 - mean_squared_error: 0.0277 - val_loss: 0.0187 - val_mean_squared_error: 0.0138
#
# Epoch 00010: val_loss did not improve from 0.01615
# Epoch 11/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0324 - mean_squared_error: 0.0276 - val_loss: 0.0142 - val_mean_squared_error: 0.0095
#
# Epoch 00011: val_loss improved from 0.01615 to 0.01416, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 12/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0323 - mean_squared_error: 0.0276 - val_loss: 0.0171 - val_mean_squared_error: 0.0125
#
# Epoch 00012: val_loss did not improve from 0.01416
# Epoch 13/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0324 - mean_squared_error: 0.0279 - val_loss: 0.0257 - val_mean_squared_error: 0.0212
#
# Epoch 00013: val_loss did not improve from 0.01416
# Epoch 14/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0317 - mean_squared_error: 0.0274 - val_loss: 0.0161 - val_mean_squared_error: 0.0116
#
# Epoch 00014: val_loss did not improve from 0.01416
# Epoch 15/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0321 - mean_squared_error: 0.0278 - val_loss: 0.0364 - val_mean_squared_error: 0.0320
#
# Epoch 00015: val_loss did not improve from 0.01416
# Epoch 16/150
# 178603/178603 [==============================] - 10s 57us/step - loss: 0.0314 - mean_squared_error: 0.0272 - val_loss: 0.0142 - val_mean_squared_error: 0.0101
#
# Epoch 00016: val_loss did not improve from 0.01416
# Epoch 17/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0319 - mean_squared_error: 0.0278 - val_loss: 0.0287 - val_mean_squared_error: 0.0247
#
# Epoch 00017: val_loss did not improve from 0.01416
# Epoch 18/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0312 - mean_squared_error: 0.0272 - val_loss: 0.0109 - val_mean_squared_error: 0.0067
#
# Epoch 00018: val_loss improved from 0.01416 to 0.01085, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 19/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0315 - mean_squared_error: 0.0275 - val_loss: 0.0173 - val_mean_squared_error: 0.0133
#
# Epoch 00019: val_loss did not improve from 0.01085
# Epoch 20/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0317 - mean_squared_error: 0.0278 - val_loss: 0.0122 - val_mean_squared_error: 0.0081
#
# Epoch 00020: val_loss did not improve from 0.01085
# Epoch 21/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0312 - mean_squared_error: 0.0273 - val_loss: 0.0194 - val_mean_squared_error: 0.0157
#
# Epoch 00021: val_loss did not improve from 0.01085
# Epoch 22/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0316 - mean_squared_error: 0.0278 - val_loss: 0.0233 - val_mean_squared_error: 0.0196
#
# Epoch 00022: val_loss did not improve from 0.01085
# Epoch 23/150
# 178603/178603 [==============================] - 10s 57us/step - loss: 0.0315 - mean_squared_error: 0.0278 - val_loss: 0.0141 - val_mean_squared_error: 0.0104
#
# Epoch 00023: val_loss did not improve from 0.01085
# Epoch 24/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0311 - mean_squared_error: 0.0273 - val_loss: 0.0206 - val_mean_squared_error: 0.0168
#
# Epoch 00024: val_loss did not improve from 0.01085
# Epoch 25/150
# 178603/178603 [==============================] - 10s 57us/step - loss: 0.0310 - mean_squared_error: 0.0272 - val_loss: 0.0150 - val_mean_squared_error: 0.0113
#
# Epoch 00025: val_loss did not improve from 0.01085
# Epoch 26/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0310 - mean_squared_error: 0.0273 - val_loss: 0.0093 - val_mean_squared_error: 0.0055
#
# Epoch 00026: val_loss improved from 0.01085 to 0.00927, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 27/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0312 - mean_squared_error: 0.0276 - val_loss: 0.0163 - val_mean_squared_error: 0.0127
#
# Epoch 00027: val_loss did not improve from 0.00927
# Epoch 28/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0315 - mean_squared_error: 0.0278 - val_loss: 0.0139 - val_mean_squared_error: 0.0104
#
# Epoch 00028: val_loss did not improve from 0.00927
# Epoch 29/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0315 - mean_squared_error: 0.0278 - val_loss: 0.0112 - val_mean_squared_error: 0.0076
#
# Epoch 00029: val_loss did not improve from 0.00927
# Epoch 30/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0315 - mean_squared_error: 0.0278 - val_loss: 0.0291 - val_mean_squared_error: 0.0256
#
# Epoch 00030: val_loss did not improve from 0.00927
# Epoch 31/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0314 - mean_squared_error: 0.0278 - val_loss: 0.0072 - val_mean_squared_error: 0.0037
#
# Epoch 00031: val_loss improved from 0.00927 to 0.00719, saving model to ./model/K8_PA_simpleStructure.h5
# Epoch 32/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0313 - mean_squared_error: 0.0277 - val_loss: 0.0092 - val_mean_squared_error: 0.0057
#
# Epoch 00032: val_loss did not improve from 0.00719
# Epoch 33/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0306 - mean_squared_error: 0.0270 - val_loss: 0.0091 - val_mean_squared_error: 0.0056
#
# Epoch 00033: val_loss did not improve from 0.00719
# Epoch 34/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0310 - mean_squared_error: 0.0275 - val_loss: 0.0146 - val_mean_squared_error: 0.0110
#
# Epoch 00034: val_loss did not improve from 0.00719
# Epoch 35/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0315 - mean_squared_error: 0.0279 - val_loss: 0.0129 - val_mean_squared_error: 0.0093
#
# Epoch 00035: val_loss did not improve from 0.00719
# Epoch 36/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0312 - mean_squared_error: 0.0276 - val_loss: 0.0079 - val_mean_squared_error: 0.0043
#
# Epoch 00036: val_loss did not improve from 0.00719
# Epoch 37/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0312 - mean_squared_error: 0.0277 - val_loss: 0.0093 - val_mean_squared_error: 0.0058
#
# Epoch 00037: val_loss did not improve from 0.00719
# Epoch 38/150
# 178603/178603 [==============================] - 10s 55us/step - loss: 0.0310 - mean_squared_error: 0.0275 - val_loss: 0.0122 - val_mean_squared_error: 0.0087
#
# Epoch 00038: val_loss did not improve from 0.00719
# Epoch 39/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0311 - mean_squared_error: 0.0276 - val_loss: 0.0124 - val_mean_squared_error: 0.0090
#
# Epoch 00039: val_loss did not improve from 0.00719
# Epoch 40/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0310 - mean_squared_error: 0.0275 - val_loss: 0.0188 - val_mean_squared_error: 0.0154
#
# Epoch 00040: val_loss did not improve from 0.00719
# Epoch 41/150
# 178603/178603 [==============================] - 10s 56us/step - loss: 0.0311 - mean_squared_error: 0.0277 - val_loss: 0.0267 - val_mean_squared_error: 0.0234
#
# Epoch 00041: val_loss did not improve from 0.00719

# %%
# plot history
plt.plot(hist_1.history['loss'][1:], label='train')
plt.plot(hist_1.history['val_loss'][1:], label='test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model = load_model('./model/K8_PA_simpleStructure.h5')

# %%
#Training error Check
y_pred = pd.DataFrame(model.predict(x_test_scaled), columns=['dlt_x','dlt_y','dlt_z','ax_pred','ay_pred','az_pred'])

# %%
del_x_idx, = np.where(abs(y_test_scaled['dlt_x'] - y_pred.iloc[:,0]) > 12)
del_y_idx, = np.where(abs(y_test_scaled['dlt_y'] - y_pred.iloc[:,1]) > 12)
del_z_idx, = np.where(abs(y_test_scaled['dlt_z'] - y_pred.iloc[:,2]) > 12)

del_idx = set(del_x_idx) | set(del_y_idx) | set(del_z_idx)

y_test_scaled = y_test_scaled.loc[y_test_scaled.index.drop(list(del_idx))].reset_index(drop=True)
y_pred = y_pred.loc[y_pred.index.drop(list(del_idx))].reset_index(drop=True)

# %%
y_test_inverse = pd.DataFrame(y_scaler.inverse_transform(y_test_scaled))
y_pred_inverse = pd.DataFrame(y_scaler.inverse_transform(y_pred))

# %%
fig = plt.figure(figsize=(10,10))

ax1 = fig.add_subplot(3,3,1)
ax2 = fig.add_subplot(3,3,2)
ax3 = fig.add_subplot(3,3,3)
ax4 = fig.add_subplot(3,3,4)
ax5 = fig.add_subplot(3,3,5)
ax6 = fig.add_subplot(3,3,6)

ax1.scatter(y_test_inverse.iloc[:,0], y_pred_inverse.iloc[:,0], s= 2)
ax1.set_xlabel('dlt_x_real')
ax1.set_ylabel('dlt_x_pred')
ax1.xaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))
ax1.yaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))

ax2.scatter(y_test_inverse.iloc[:,1], y_pred_inverse.iloc[:,1], s= 2)
ax2.set_xlabel('dlt_y_real')
ax2.set_ylabel('dlt_y_pred')
ax2.xaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))
ax2.yaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))

ax3.scatter(y_test_inverse.iloc[:,2], y_pred_inverse.iloc[:,2], s= 2)
ax3.set_xlabel('dlt_z_real')
ax3.set_ylabel('dlt_z_pred')
ax3.xaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))
ax3.yaxis.set_ticks(np.arange(-0.03, 0.04, 0.03))

ax4.scatter(y_test_inverse.iloc[:,3], y_pred_inverse.iloc[:,3], s= 2)
ax4.set_xlabel('ax_real')
ax4.set_ylabel('ax_pred')
ax4.xaxis.set_ticks(np.arange(-15, 16, 15))
ax4.yaxis.set_ticks(np.arange(-15, 16, 15))
ax5.scatter(y_test_inverse.iloc[:,4], y_pred_inverse.iloc[:,4], s= 2)
ax5.set_xlabel('ay_real')
ax5.set_ylabel('ay_pred')
ax5.xaxis.set_ticks(np.arange(-15, 16, 15))
ax5.yaxis.set_ticks(np.arange(-15, 16, 15))
ax6.scatter(y_test_inverse.iloc[:,5], y_pred_inverse.iloc[:,5], s= 2)
ax6.set_xlabel('az_real')
ax6.set_ylabel('az_pred')
ax6.xaxis.set_ticks(np.arange(-15, 16, 15))
ax6.yaxis.set_ticks(np.arange(-15, 16, 15))

plt.subplots_adjust(wspace = 1, hspace = 0.5)
plt.show()

# %%
#position error
print('rmse:', np.sqrt(mean_squared_error(y_test_inverse.iloc[:,0:3], y_pred_inverse.iloc[:,0:3])))
print('mae:', mean_absolute_error(y_test_inverse.iloc[:,0:3], y_pred_inverse.iloc[:,0:3]))
print('r2:', r2_score(y_test_inverse.iloc[:,0:3], y_pred_inverse.iloc[:,0:3]))

print('\n')
#position error
print('rmse:', np.sqrt(mean_squared_error(y_test_inverse.iloc[:,3:6], y_pred_inverse.iloc[:,3:6])))
print('mae:', mean_absolute_error(y_test_inverse.iloc[:,3:6], y_pred_inverse.iloc[:,3:6]))
print('r2:', r2_score(y_test_inverse.iloc[:,3:6], y_pred_inverse.iloc[:,3:6]))
# Out:
# rmse: 0.0002940011333707039
# mae: 0.00022015761275924134
# r2: 0.9972465831941234
#
#
# rmse: 0.19059049401995878
# mae: 0.14873623992851567
# r2: 0.9952903995083645
